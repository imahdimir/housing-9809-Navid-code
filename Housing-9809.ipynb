# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

pd.set_option('display.max_columns', None)
pd.set_option('display.max_rows', None)
pd.set_option('display.float_format', lambda x: '%.2f' % x)

# %%
df_main = pd.DataFrame()

# %%
df = pd.read_excel('Iran_Maskan_koll_9808_.xlsx')

# %%
df.dropna(thresh=2, inplace=True)

df.columns=df.iloc[0,:]

df = df.iloc[:,3:]

df = df.iloc[1:,:]

df_main = df_main.append(df)
# Out:
# C:\Users\MHDR\Anaconda3\lib\site-packages\pandas\core\frame.py:6211: FutureWarning: Sorting because non-concatenation axis is not aligned. A future version
# of pandas will change to not sort by default.
#
# To accept the future behavior, pass 'sort=False'.
#
# To retain the current behavior and silence the warning, pass 'sort=True'.
#
#   sort=sort)

# %%
df = pd.read_excel('Iran_maskan_koll9612.xlsx')

# %%
df = pd.read_excel('Iran_Maskan_koll9803.xlsx')

# %%
df = pd.read_excel('Iran_Maskan_koll9804.xlsx')

# %%
df = pd.read_excel('Iran_Maskan_koll9807.xlsx')

# %%
df = df_main

# %%
df = df_main

df = df.iloc[:,[0,2,3,5,6,7,8,9,11,12,18]]

df.columns=['add1', 'state', 'date', 'add6', 'city', 'age', 'price', 'ppm', 'area', 'mun', 'zip']

df = df[df.city=='تهران']

#df = df[df.area==210]

df.price = df.price.astype(float)/10**7

df.ppm = df.ppm.astype(float)/10**4

df['zipcode'] = np.where(df.add1.isnull(), df.add6, df.add1) 

df = df[['zipcode', 'date','price', 'ppm', 'area', 'age','mun']]

df.zipcode.astype(float)
df.area.astype(float)
df.age.astype(float)
df.reset_index(inplace=True, drop=True)

# %%
df = df[df.mun==7]

# %%
df = df.sort_values('price')

# %%
df.describe()
# Out:
#        price    ppm
# count 881.00 881.00
# mean    1.02  12.16
# std     0.80   5.30
# min     0.00   0.00
# 25%     0.49   8.96
# 50%     0.80  11.08
# 75%     1.30  14.93
# max     7.20  40.00

# %%
df
# Out:
#       zipcode        date  price   ppm   area age mun
# 27425  159681  1398/06/27   0.00  0.00 116.72   5   7
# 29623  158785  1398/07/08   0.01  0.12  82.60  46   7
# 27368  157973  1398/06/17   0.01  0.07 106.18   3   7
# 26960  163785  1398/06/25   0.04  0.59  31.85  19   7
# 26104  173691  1398/06/11   0.09  0.22  68.66   7   7
# 30362  161865  1398/07/23   0.10  2.31  43.27   7   7
# 1187   161596  1398/08/12   0.15  2.09     70   0   7
# 23904  163874  1398/04/16   0.15  2.95  50.85  14   7
# 26917  111997  1398/06/26   0.16  4.00  40.50  13   7
# 45     156561  1398/08/01   0.17  1.96  43.28   8   7
# 24326  157375  1398/04/18   0.17  0.62  94.05  14   7
# 3588   163973  1398/08/29   0.20  3.11  64.24  11   7
# 31284  157371  1398/07/18   0.20  2.15     93  18   7
# 25588  114776  1398/04/27   0.20  3.04  65.79  16   7
# 26599  164163  1398/06/13   0.21 10.60     20   0   7
# 898    163785  1398/08/11   0.21  5.25  40.92  27   7
# ...
